# %%
import cv2 
import os 
import moviepy
# Read the video from specified path 
cam = cv2.VideoCapture("/data/HuToM/01_RawData/03_Gastric_HDD/Video_Segmentation/R00006/ch1_video_01.mp4") 
  
try: 
      
    # creating a folder named data 
    if not os.path.exists('validData'): 
        os.makedirs('validData') 
  
# if not created then raise error 
except OSError: 
    print ('Error: Creating directory of data') 
  
# frame 
currentframe = 0
  
while(True): 
      
    # reading from frame 
    ret,frame = cam.read() 
  
    if ret: 
        # if video is still left continue creating images 
        if currentframe % 100 == 0:
            
            name = './validData/R00006/ch1_video_01_frame' + str(currentframe) + '.jpg'
            print ('Creating...' + name) 

            # writing the extracted images 
            cv2.imwrite(name, frame) 
    
            # increasing counter so that it will 
            # show how many frames are created 
        
        currentframe += 1
    else: 
        break
  
# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Creating..../validData/r00006/ch1_video_01_frame0.jpg
# Creating..../validData/r00006/ch1_video_01_frame100.jpg
# Creating..../validData/r00006/ch1_video_01_frame200.jpg
# Creating..../validData/r00006/ch1_video_01_frame300.jpg
# Creating..../validData/r00006/ch1_video_01_frame400.jpg
# Creating..../validData/r00006/ch1_video_01_frame500.jpg
# Creating..../validData/r00006/ch1_video_01_frame600.jpg
# Creating..../validData/r00006/ch1_video_01_frame700.jpg
# Creating..../validData/r00006/ch1_video_01_frame800.jpg
# Creating..../validData/r00006/ch1_video_01_frame900.jpg
# Creating..../validData/r00006/ch1_video_01_frame1000.jpg
# Creating..../validData/r00006/ch1_video_01_frame1100.jpg
# Creating..../validData/r00006/ch1_video_01_frame1200.jpg
# Creating..../validData/r00006/ch1_video_01_frame1300.jpg
# Creating..../validData/r00006/ch1_video_01_frame1400.jpg
# Creating..../validData/r00006/ch1_video_01_frame1500.jpg
# Creating..../validData/r00006/ch1_video_01_frame1600.jpg
# Creating..../validData/r00006/ch1_video_01_frame1700.jpg
# Creating..../validData/r00006/ch1_video_01_frame1800.jpg
# Creating..../validData/r00006/ch1_video_01_frame1900.jpg
# Creating..../validData/r00006/ch1_video_01_frame2000.jpg
# Creating..../validData/r00006/ch1_video_01_frame2100.jpg
# Creating..../validData/r00006/ch1_video_01_frame2200.jpg
# Creating..../validData/r00006/ch1_video_01_frame2300.jpg
# Creating..../validData/r00006/ch1_video_01_frame2400.jpg
# Creating..../validData/r00006/ch1_video_01_frame2500.jpg
# Creating..../validData/r00006/ch1_video_01_frame2600.jpg
# Creating..../validData/r00006/ch1_video_01_frame2700.jpg
# Creating..../validData/r00006/ch1_video_01_frame2800.jpg
# Creating..../validData/r00006/ch1_video_01_frame2900.jpg
# Creating..../validData/r00006/ch1_video_01_frame3000.jpg
# Creating..../validData/r00006/ch1_video_01_frame3100.jpg
# Creating..../validData/r00006/ch1_video_01_frame3200.jpg
# Creating..../validData/r00006/ch1_video_01_frame3300.jpg
# Creating..../validData/r00006/ch1_video_01_frame3400.jpg
# Creating..../validData/r00006/ch1_video_01_frame3500.jpg
# Creating..../validData/r00006/ch1_video_01_frame3600.jpg
# Creating..../validData/r00006/ch1_video_01_frame3700.jpg
