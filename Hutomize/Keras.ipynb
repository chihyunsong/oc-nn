# %%
from src.KerasDataset import SurgicalDataset

# %%
sg = SurgicalDataset('data')
# Out:
# Train Directory: /tf/Hutomize/data/
# Found 199943 images belonging to 3 classes.

# %%
dataset = sg.getIterator()
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
 ss = next(dataset)

# %%
plt.imshow(ss[0][8])

# %%
plt.imshow(ss[1][8])
